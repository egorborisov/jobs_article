# %%
import re
import pandas as pd
import numpy as np
from tqdm import tqdm_notebook as tqdm
from langdetect import detect

# %%
jobs = pd.read_csv('processed_data/jobs_data.csv')

# %%
def search_fork(text):
    text = text.lower()
    regexs = [r'вилк', r'зп', r'з/п', r'з\п', r'зарплат', r'заработн', r'оплат',
              r'компенсац', r'доход', 'fork:', r'moneys', r'salary', r'moneyparrot:', r'деньг', r'оклад', r'условия:', 
              r'ставка', r'_plug:']
    i = 0
    salary = None
    nums = None
    while i<len(regexs) and salary is None :
        salary, nums = search_keyword(regexs[i], text)
        if nums is None: 
            salary = None
            salary, nums = search_keyword(regexs[i], text, True)
            if nums is None: salary = None
        i += 1
    return salary, nums

# %%
def search_keyword(word, text, with_ent=False):
    finder = re.search(word, text)
    salary = None
    nums = None
    if finder:
        start = finder.start()
        salary = ''
        text_s = text[start:]
        for i, ch in enumerate(text_s):
            if ch != '\n' and i != len(text_s)-1:
                salary += ch
            else:
                if with_ent == False:
                    nums = search_numbers_in_salary_text(salary)
                    return salary, nums
                else:
                    salary += ch
                    with_ent = False
    return salary, nums

# %%
def search_numbers_in_salary_text(text):
    if text is None: return None
    nums = []
    num = ''
    for ch in text:
        if ch.isdigit() or ch in ('.'):
            if len(num)==0 and ch=='0' and len(nums)>0:
                num = nums.pop()
            num += ch
        else:
            if len(num)>0:
                try: 
                    float(num)
                    nums.append(num)
                except Exception as e:
                    pass
            num = ''
            
    if len(num)>0 and num!='.': nums.append(num)
    return nums if nums else None

# %%
def search_for_salary(text):
    regex = r'\d{2,6}[-докКтысрщ.]{1,4}\d{2,6}\s?(?:к|К|тыс|тысяч|т\s?р|т.\s?р.|gross|net)?'
    # Почему-то неправильная регулярка:(
    # regex = r'\d{2,6}[-докКтысрщ.](?:{1,4}\d{2,6}\s?(?:к|К|тыс|тысяч|т\s?р|т.\s?р.|gross|net)?)?'
    result = re.findall(regex, text, flags=re.IGNORECASE)
    return result


def get_salaries(data):
    salary = []
    nums = []
    is_eng = []
    for d in tqdm(data.itertuples()):
        if detect(d.text) != 'ru':
            is_eng.append(1)
        else:
            is_eng.append(0)
        res, num = search_fork(d.text)
        if nums is not None:
            nums.append(num)
            salary.append(res)
#         ids.append(i)
    return salary, nums, is_eng

# %%
salary, nums, is_eng = get_salaries(jobs)
# Out:
# <ipython-input-62-1b40958a7211>:13: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for d in tqdm(data.itertuples()):
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…

# %%
jobs['salary'] = salary
jobs['nums'] = nums
jobs['is_eng'] = is_eng

# %% [markdown]
# ### Проверка парсинга

# %%
# процент вакансий с нераспаршенными зп
100*jobs['salary'].isnull().sum()/jobs.shape[0], jobs['salary'].isnull().sum()
# Out:
# (16.42542479546885, 522)

# %%
jobs[['salary', 'nums', 'text']].tail(30)#['text'][2]
# Out:
#                                                  salary  \
# 3148                                   вилка* - 160-250
# 3149                 вилка: *150 000 – 250 000* руб/мес
# 3150                 вилка: *150 000 – 250 000* руб/мес
# 3151                                               None
# 3152  вилка: нетто* 60k - 100k rub/month + годовой б...
# 3153  вилка:* <tel:144 000 -180000|144 000 -180000> ...
# 3154  ставка может обсуждаться индивидуально! от 400...
# 3155  вилка: gross*\n• middle: 150 - 200к + годовой ...
# 3156                            вилка 150k-250k ₽ (net)
# 3157                              вилка:* 80 - 120к net
# 3158                              вилка*: 230-250 gross
# 3159                             вилка: 110-180 на руки
# 3160  вилка: нетто 80k - 100k rub/month + годовой бо...
# 3161                       вилка* (150 т.р. – 300 т.р.)
# 3162                 вилка: *150 000 – 250 000* руб/мес
# 3163                 вилка: *150 000 – 250 000* руб/мес
# 3164                                 вилка:* 150 – 180к
# 3165  salary* (2500 euro – 8000 euro) + *end-year pe...
# 3166                                               None
# 3167  зп: 300-500 k (финальные цифры по итогам собес...
# 3168  зп: от 130-190 т.р. на руки+ годовые премии от...
# 3169                      salary ranging within $3-5.5k
# 3170  оклад 100-200к руб на руки по тк рф + полугодо...
# 3171  оклад 180-250к руб на руки по тк рф + полугодо...
# 3172                              зп: от 1500 до 3000 $
# 3173  зп: 150-300 k (финальные цифры по итогам собес...
# 3174  зп: 250-400 к (финальные цифры по итогам собес...
# 3175       условия:*\n100 000 до 120 000 рублей на руки
# 3176                 вилка: *150 000 – 250 000* руб/мес
# 3177                         з/п: 200-250 тыс. руб/мес*
#
#                                         nums  \
# 3148                              [160, 250]
# 3149                        [150000, 250000]
# 3150                        [150000, 250000]
# 3151                                    None
# 3152                            [60, 100, 2]
# 3153  [144000, 180000, 144000, 180000, 2, 4]
# 3154                            [4000, 1, 5]
# 3155                        [150, 200, 2, 5]
# 3156                              [150, 250]
# 3157                               [80, 120]
# 3158                              [230, 250]
# 3159                              [110, 180]
# 3160                            [80, 100, 2]
# 3161                              [150, 300]
# 3162                        [150000, 250000]
# 3163                        [150000, 250000]
# 3164                              [150, 180]
# 3165                            [2500, 8000]
# 3166                                    None
# 3167                              [300, 500]
# 3168                           [130, 190, 2]
# 3169                                [3, 5.5]
# 3170                              [100, 200]
# 3171                              [180, 250]
# 3172                            [1500, 3000]
# 3173                              [150, 300]
# 3174                              [250, 400]
# 3175                        [100000, 120000]
# 3176                        [150000, 250000]
# 3177                              [200, 250]
#
#                                                    text
# 3148  *вакансия: devops (системный администратор)*\n...
# 3149  компания:  :sber_new:*сбербанк*\nгород: москва...
# 3150  компания: :sber_new:*сбербанк*\nгород: москва ...
# 3151  *senior software engineer (python/devops/data ...
# 3152  *название вакансии:* project manager команды а...
# 3153  всем привет!\n*компания*: сбербанк\n*локация*:...
# 3154  преподаватель на онлайн курс data engineer для...
# 3155  всем привет!\nкомпания: сбербанк.\n*локация*: ...
# 3156  :spock-hand:\n*photo lab*  -  <https://pho.to>...
# 3157  *роль:* data engineer\n*компания:* <http://www...
# 3158  - **вакансия**: *data engineer*\n *компания*: ...
# 3159  вакансия: <http://factory5.ai|factory5.ai> mid...
# 3160  название вакансии: project manager команды ана...
# 3161  мопед не мой)\n\n*вакансия*: data analyst в фи...
# 3162  компания: :sber_new:*сбербанк*\nгород: москва ...
# 3163  компания: :sber_new:*сбербанк*\nгород: москва ...
# 3164  *компания:* gfaive (<http://www.gfaive.com|www...
# 3165  hi @chanel,\n\ni'm nikita dolzhikov, i'm leadi...
# 3166  *security analyst, open source security, 80-12...
# 3167  привет, друзья!\n\nяндекс ищет *team lead, ана...
# 3168  #вакансия #scala #москва #spark #dataengineer\...
# 3169  hey there, while you kicked off the productive...
# 3170  *вакансия: data analyst*\n*команда:* data анал...
# 3171  *вакансия: python developer (senior or middle)...
# 3172  #вакансия #ds #минск #datascientist\nвакансия:...
# 3173  друзья, коллеги и вновь, здравствуйте!\n\nянде...
# 3174  - вакансия: head of data engineering\nгород: м...
# 3175  *clickio*, международная it-компания, ищет *ст...
# 3176  компания: :sber_new:*сбербанк*\nгород: москва ...
# 3177  *компания: ао юникредит банк*\n*позиция: senio...

# %%
jobs[jobs['is_eng']==1][['salary', 'nums', 'text']].tail(30)
# Out:
#                                                  salary  \
# 2994                              вилка: 2000$ - 3500$*
# 2999       salary range  :* 120-200+ gross (+bonus 20%)
# 3007                     salary_:* up to 52k€ + bonuses
# 3014                                               None
# 3027                                               None
# 3029            salary: * 140 000 - 200 000 rub/monthly
# 3037                                               None
# 3040  зп (от 180к до 240к рублей net, с интересным к...
# 3049  fork:: 12-16k $ (это моя оценка на основе знан...
# 3050                  вилка: 120 - 150 000 рублей gross
# 3051  зп, но зато плюшек много, типа полетов на эмир...
# 3063  fork: : from $18k to $48k net annual depending...
# 3075                 вилка:* €60-75k (в год до налогов)
# 3083  вилка: минимум 50k usd  в год gross, максимум ...
# 3087  salary (2500 euro – 8000 euro) + performance b...
# 3091  salary (2500 euro – 8000 euro) + performance b...
# 3097  salary of 2100 - 3300 eur (1300 - 2000 eur net...
# 3111                       вилка зарплаты: $1200-$2200*
# 3123                       вилка:* $3000-3500/month net
# 3131                                               None
# 3137                                               None
# 3138                                               None
# 3141                                               None
# 3143                                               None
# 3144                  salary: 400k-700k rubles / month*
# 3145                                               None
# 3151                                               None
# 3165  salary* (2500 euro – 8000 euro) + *end-year pe...
# 3166                                               None
# 3169                      salary ranging within $3-5.5k
#
#                                  nums  \
# 2994                     [2000, 3500]
# 2999                   [120, 200, 20]
# 3007                             [52]
# 3014                             None
# 3027                             None
# 3029                 [140000, 200000]
# 3037                             None
# 3040                       [180, 240]
# 3049                     [12, 16, 12]
# 3050                    [120, 150000]
# 3051                         [50, 90]
# 3063                         [18, 48]
# 3075                         [60, 75]
# 3083                        [50, 200]
# 3087                     [2500, 8000]
# 3091                     [2500, 8000]
# 3097  [2100, 3300, 1300, 2000, 1, 40]
# 3111                     [1200, 2200]
# 3123                     [3000, 3500]
# 3131                             None
# 3137                             None
# 3138                             None
# 3141                             None
# 3143                             None
# 3144                       [400, 700]
# 3145                             None
# 3151                             None
# 3165                     [2500, 8000]
# 3166                             None
# 3169                         [3, 5.5]
#
#                                                    text
# 2994  *вторая:* :flag-ua:\n\n*компания: parimatch uk...
# 2999  *job title* : junior+/middle data scientist \n...
# 3007  hi everyone,\n\ndiagnoly is looking for a seni...
# 3014  ```\nвсем привет!\nк нам в kaspersky lab ищем ...
# 3027  scalarr is an international mobile anti-fraud ...
# 3029  hello!\ni'm a recruiter in prophecy labs and w...
# 3037  всем привет! в команду развития бизнеса nvidia...
# 3040  всем привет!\nищем: data engineer\nпроект: мас...
# 3049  от себя:\n- контору знаю в которую ищут, но го...
# 3050  вакансии: data analyst\nгород: москва\nкомпани...
# 3051  мопед не мой, так что пощу сюда, но контакты у...
# 3063  company: sideways 6 development (<https://www....
# 3075  мопед не мой, попросили запостить вакансию.\n\...
# 3083  добрый день!\n\nищется специалист machine lear...
# 3087  *mckinsey &amp; company* is actively still loo...
# 3091  *mckinsey &amp; company* eema data science hub...
# 3097  всем привет! публикую по просьбе знакомых.\n\n...
# 3111  всем привет!\nвелосипед не мой, знакомые попро...
# 3123  всем привет!\n\n*компания: <http://locationsci...
# 3131  machine learning engineer\n<http://ydata.ai|yd...
# 3137  всем привет! японский стартап ищет себе специа...
# 3138  *senior computer vision data scientist, 120-20...
# 3141  *ml engineering manager, 80-140k usd annual, b...
# 3143  *ml security senior engineer, 50-130k usd, sf/...
# 3144  кратко: западная компания открывает представит...
# 3145  *lead machine learning engineer at a stealth b...
# 3151  *senior software engineer (python/devops/data ...
# 3165  hi @chanel,\n\ni'm nikita dolzhikov, i'm leadi...
# 3166  *security analyst, open source security, 80-12...
# 3169  hey there, while you kicked off the productive...

# %%
jobs[(jobs.nums.isnull())&(jobs.is_eng==0)][['text', 'salary']].tail(20)
# Out:
#                                                    text salary
# 2687  и снова привет! ещё две вакансии от *astral ai...   None
# 2701  *компания:* лента :lenta:, big data department...   None
# 2751  подарок на нг)\nвакансия фулстак софтверщика в...   None
# 2778  всем привет! :wave:\n\n*после фидбека от ods п...   None
# 2784  всем привет!\nмы в *<https://www.semrush.com/|...   None
# 2870  привет ods. меня зовут паша, я научный сотрудн...   None
# 2878  *вакансия: lead nlp researcher/tech lead в лаб...   None
# 2880  • опыт работы от 3 лет в сфере обработки аудио...   None
# 2881  всем привет:wave:\n\nнаша data science-команда...   None
# 2911  после первых публикаций к нам уже пришли класс...   None
# 2918  всем привет!\n\n «*uma.tech*», технологическая...   None
# 2952  всем привет!\n\n*кого ищем*: marketing analyst...   None
# 2954  *вакансия:* jun/mid ml engineer\n*компания:* <...   None
# 2967  вакансия = *middle data engineer*\nкомпания = ...   None
# 3013  ```oleg_art [11:10 am]\nраз пост в ods помогае...   None
# 3015  ```\n*функциональная группа ai, центр инноваци...   None
# 3016  ```\n*функциональная группа ai, центр инноваци...   None
# 3084  всем привет! попросили выложить, все вопросы —...   None
# 3113  всем привет! поправьте меня, если пишу не в то...   None
# 3132  салют! ищем человека на позицию *senior ml eng...   None

# %% [markdown]
# #### Надо придумать регулярку для парсинга вакансий без ключевых слов

# %%
jobs['text'][2687]
# Out:
# 'и снова привет! ещё две вакансии от *astral ai*, на этот раз в медицинскую команду.\n*компания*: astral ai\n*команда*: <http://celsus.ai|цельс>\n*локация*: петербург, невский проспект\n*занятость*: full-time\n*позиция 1*: специалист в области computer vision (middle/senior), 130-180 middle, 180-300 senior (net)\n*позиция 2*: аналитик по медицинским данным (junior), 60-120 (net)\n\n*мы ищем тех, кто*\n• хочет работать в энергичной, слегка чокнутой команде\n• не боится рисковать и принимать важные решения\n• умеет слушать чужие мнения и не стесняется высказывать своё\n• готов работать в условиях не до конца сформированного, хаотичного рынка медицинских ai-технологий\n• не падает в обморок при виде рентгеновских снимков и готов регулярно впитывать сакральные медицинские знания от врачей\n*наши проекты:*\n• маммография - детектирование злокачественных и доброкачественных образований на снимках молочной железы. мы - первая команда, прошедшая в продуктовый контур эксперимента по использованию сервисов на основе технологий ии в системе здравоохранения города москвы. \n• флюорография - классификация и сегментация патологических изменений грудной клетки. удивительно, но и здесь мы первые (и пока единственные), кто работает в рамках московского эксперимента.\n• кт лёгких - сегментация злокачественных образований и признаков covid-19.\n• гистологические исследования - сегментация областей интереса\nописание позиций в треде\n\nпишите на почту\xa0<mailto:hr-ai@astral.ru|hr-ai@astral.ru>, не забывайте прикреплять резюме и ссылку на гитхаб (если есть). в тему письма обязательно добавляйте название команды и позиции, письма без темы имеют шанс остаться незамеченными.'
